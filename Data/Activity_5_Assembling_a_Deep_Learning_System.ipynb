# %% [markdown]
# # Activity 5: Assembling a Deep Learning System
# In this activity, we will train the first version of our LSTM model using Bitcoin daily closing prices. These prices will be organized using the weeks of both 2016 and 2017. We do that because we are interested in predicting the prices of a week's worth of trading.

# %%
# %autosave 5

#  Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')

from keras.models import load_model
# Out:
# Autosaving every 5 seconds

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#  Import training dataset
train = pd.read_csv('/content/drive/My Drive/Data/train_dataset.csv')
train.head()
# Out:
#          date  ... volume_point_relative_normalization
# 0  2016-01-01  ...                            0.000000
# 1  2016-01-02  ...                           -0.170410
# 2  2016-01-03  ...                            0.000000
# 3  2016-01-04  ...                           -0.029175
# 4  2016-01-05  ...                           -0.128961
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Reshape Data

# %%
def create_groups(data, group_size=7):
    """Create distinct groups from a continuous series.
    
    Parameters
    ----------
    data: np.array
        Series of continious observations.

    group_size: int, default 7
        Determines how large the groups are. That is,
        how many observations each group contains.
    
    Returns
    -------
    A Numpy array object. 
    """
    samples = []
    for i in range(0, len(data), group_size):
        sample = list(data[i:i + group_size])
        if len(sample) == group_size:
            samples.append(np.array(sample).reshape(1, group_size))
    
    return np.array(samples)

# %%
#  Find the remainder when the number of observations is divided by group size
len(train) % 7
# Out:
# 77

# %%
#  Create groups of 7 from our data.
#  We drop the first two observations so that the
#  number of total observations is divisible by the `group_size`.
data = create_groups(train['close_point_relative_normalization'][2:].values)
print(data.shape)
# Out:
# (77, 1, 7)

# %%
#  Reshape data into format expected by LSTM layer
X_train = data[:-1, :].reshape(1, 76, 7)
Y_validation = data[-1].reshape(1, 7)
print(X_train.shape)
print(Y_validation.shape)
# Out:
# (1, 76, 7)
# (1, 7)

# %% [markdown]
# ## Load Our Model

# %%
#  Load our previously trained model 
model = load_model('/content/drive/My Drive/Data/bitcoin_lstm_v1.h5')

# %% [markdown]
# ## Train model

# %%
# %%time
#  Train the model
history = model.fit(
    x=X_train, y=Y_validation,
    batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 13/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1324e-04 - accuracy: 1.0000
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2614e-04 - accuracy: 1.0000
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.4481e-04 - accuracy: 1.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6908e-04 - accuracy: 1.0000
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9883e-04 - accuracy: 1.0000
# Epoch 19/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3397e-04 - accuracy: 1.0000
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7442e-04 - accuracy: 1.0000
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2000e-04 - accuracy: 1.0000
# Epoch 22/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7049e-04 - accuracy: 1.0000
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2558e-04 - accuracy: 1.0000
# Epoch 24/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8492e-04 - accuracy: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4817e-04 - accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1497e-04 - accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8503e-04 - accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5808e-04 - accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3393e-04 - accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1241e-04 - accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3403e-05 - accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.6787e-05 - accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2453e-05 - accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0277e-05 - accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0112e-05 - accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1787e-05 - accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5104e-05 - accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9848e-05 - accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5799e-05 - accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2743e-05 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0489e-05 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8726e-06 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.7673e-06 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0759e-06 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.7263e-06 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6610e-06 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.8273e-06 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1696e-06 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6267e-06 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.1322e-06 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.6199e-06 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.0301e-06 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3162e-06 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4481e-06 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.4140e-06 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2178e-06 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.8749e-06 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4073e-06 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.8394e-06 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1953e-06 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4978e-06 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7680e-06 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0265e-06 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2939e-06 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5906e-06 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9358e-06 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3465e-06 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8352e-06 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4090e-06 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0691e-06 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.1070e-07 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2452e-07 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9829e-07 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1871e-07 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7303e-07 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5029e-07 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4183e-07 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4136e-07 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4456e-07 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4858e-07 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5154e-07 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5215e-07 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4959e-07 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4342e-07 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3363e-07 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2062e-07 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0510e-07 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8792e-07 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6987e-07 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5154e-07 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3319e-07 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1484e-07 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9631e-07 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7746e-07 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5826e-07 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3891e-07 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1982e-07 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0157e-07 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4760e-08 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9863e-08 - accuracy: 1.0000
# CPU times: user 3.46 s, sys: 167 ms, total: 3.62 s
# Wall time: 3.54 s

# %%
#  Plot loss function
pd.Series(history.history['loss']).plot(figsize=(14, 4));

# %% [markdown]
# ## Make Predictions

# %%
#  Make predictions using X_train data
predictions = model.predict(x=X_train)[0]
predictions
# Out:
# array([0.00011464, 0.0162309 , 0.06795567, 0.05473778, 0.06145254,
#        0.07691538, 0.02369721], dtype=float32)

# %%
def denormalize(series, last_value):
    """Denormalize the values for a given series.
    
    This uses the last value available (i.e. the last
    closing price of the week before our prediction)
    as a reference for scaling the predicted results.
    """
    result = last_value * (series + 1)
    return result

# %%
#  Denormalize predictions
last_weeks_value = train[train['date'] == train['date'][:-7].max()]['close'].values[0]

denormalized_prediction = denormalize(predictions, last_weeks_value)
denormalized_prediction
# Out:
# array([2656.1846, 2698.9873, 2836.362 , 2801.2568, 2819.0903, 2860.158 ,
#        2718.817 ], dtype=float32)

# %%
#  Plot denormalized predictions against actual predictions
plt.figure(figsize=(14, 4))

plt.plot(train['close'][-7:].values, label='Actual')
plt.plot(denormalized_prediction, color='#d35400', label='Predicted')

plt.grid()
plt.legend();

# %%
prediction_plot = np.zeros(len(train)-2)
prediction_plot[:] = np.nan
prediction_plot[-7:] = denormalized_prediction

plt.figure(figsize=(14, 4))
plt.plot(train['close'][-30:].values, label='Actual')
plt.plot(prediction_plot[-30:], color='#d35400', linestyle='--', label='Predicted')
plt.axvline(30 - 7, color='r', linestyle='--', linewidth=1)

plt.grid()
plt.legend(loc='lower right');

# %%
#  TASK:
#  Save model to disk
#

# %% [markdown]
# In this activity, we have assembled a complete deep learning system: from data to prediction. The model created in this activity need a number of improvements before it can be considered useful. However, it serves as a great starting point from which we will continuously improve.

# %%
test = pd.read_csv("/content/drive/My Drive/Data/test_dataset.csv")
test.shape
# Out:
# (136, 6)

# %%
data1 = create_groups(test['close_point_relative_normalization'][2:].values)
X_test = data1[:-1, :].reshape(1, 18, 7)
Y_test = data1[-1].reshape(1, 7)
predictions_test = model.predict(x=X_train)[0]
last_weeks_value_test = test[test['date'] == test['date'][:-7].max()]['close'].values[0]

denormalized_prediction_test = denormalize(predictions_test, last_weeks_value_test)

# %%
plt.figure(figsize=(14, 4))

plt.plot(test['close'][-7:].values, label='Actual')
plt.plot(denormalized_prediction_test, color='#d35400', label='Predicted')

plt.grid()
plt.legend();
